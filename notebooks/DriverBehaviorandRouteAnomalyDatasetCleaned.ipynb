# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
import os
pd.set_option('display.max_columns', None)

# %%
print(os.getcwd())
# Out:
# C:\Users\yjany\week 4-5\notebooks

# %%
os.listdir("../Driver Behavior and Route Anomaly Dataset")
# Out:
# ['.ipynb_checkpoints',
#  'driver_behavior_route_anomaly_dataset_with_derived_features.csv']

# %%
df = pd.read_csv("../Driver Behavior and Route Anomaly Dataset/driver_behavior_route_anomaly_dataset_with_derived_features.csv")

# %%
df
# Out:
#         trip_id  driver_id  vehicle_id            timestamp   latitude  \
# 0             1        101        1001  2023-01-01 00:00:00  38.916143
# 1             2        105        2002  2023-01-01 00:00:01  37.011830
# 2             3        103        2002  2023-01-01 00:00:02  33.784009
# 3             4        102        2002  2023-01-01 00:00:03  45.314835
# 4             5        101        2002  2023-01-01 00:00:04  30.473386
# ...         ...        ...         ...                  ...        ...
# 119995   119996        101        1001  2023-01-02 09:19:55  43.054036
# 119996   119997        101        2002  2023-01-02 09:19:56  35.551541
# 119997   119998        101        1001  2023-01-02 09:19:57  41.964624
# 119998   119999        101        2002  2023-01-02 09:19:58  30.356801
# 119999   120000        101        1001  2023-01-02 09:19:59  32.707254
#
#          longitude      speed  acceleration  steering_angle     heading  \
# ...

# %%
df.dtypes
# Out:
# trip_id                           int64
# driver_id                         int64
# vehicle_id                        int64
# timestamp                        object
# latitude                        float64
# longitude                       float64
# speed                           float64
# acceleration                    float64
# steering_angle                    int64
# heading                         float64
# trip_duration                   float64
# trip_distance                   float64
# fuel_consumption                float64
# rpm                             float64
# brake_usage                       int64
# lane_deviation                  float64
# weather_conditions               object
# road_type                        object
# traffic_condition                object
# stop_events                       int64
# geofencing_violation              int64
# anomalous_event                   int64
# route_anomaly                     int64
# ...

# %%
pd.set_option('display.precision', 2)

# %%
df
# Out:
#         trip_id  driver_id  vehicle_id            timestamp  latitude  \
# 0             1        101        1001  2023-01-01 00:00:00     38.92
# 1             2        105        2002  2023-01-01 00:00:01     37.01
# 2             3        103        2002  2023-01-01 00:00:02     33.78
# 3             4        102        2002  2023-01-01 00:00:03     45.31
# 4             5        101        2002  2023-01-01 00:00:04     30.47
# ...         ...        ...         ...                  ...       ...
# 119995   119996        101        1001  2023-01-02 09:19:55     43.05
# 119996   119997        101        2002  2023-01-02 09:19:56     35.55
# 119997   119998        101        1001  2023-01-02 09:19:57     41.96
# 119998   119999        101        2002  2023-01-02 09:19:58     30.36
# 119999   120000        101        1001  2023-01-02 09:19:59     32.71
#
#         longitude  speed  acceleration  steering_angle  heading  \
# ...

# %%
df=df[['trip_id', 'driver_id', 'timestamp', 'latitude', 'longitude',
       'speed', 'acceleration', 'steering_angle', 'trip_duration',
       'trip_distance', 'fuel_consumption', 'brake_usage', 'weather_conditions',
       'road_type', 'traffic_condition', 'stop_events', 'geofencing_violation', 
       'anomalous_event', 'route_anomaly', 'route_deviation_score',	'acceleration_variation', 'behavioral_consistency_index']].copy()

# %%
df
# Out:
#         trip_id  driver_id            timestamp  latitude  longitude  speed  \
# 0             1        101  2023-01-01 00:00:00     38.92     -80.35  39.48
# 1             2        105  2023-01-01 00:00:01     37.01     -89.08   2.80
# 2             3        103  2023-01-01 00:00:02     33.78     -99.10  13.84
# 3             4        102  2023-01-01 00:00:03     45.31    -102.05  69.12
# 4             5        101  2023-01-01 00:00:04     30.47     -92.36  13.06
# ...         ...        ...                  ...       ...        ...    ...
# 119995   119996        101  2023-01-02 09:19:55     43.05     -86.20  10.26
# 119996   119997        101  2023-01-02 09:19:56     35.55     -73.44  40.43
# 119997   119998        101  2023-01-02 09:19:57     41.96     -95.33  53.89
# 119998   119999        101  2023-01-02 09:19:58     30.36     -79.89  65.56
# 119999   120000        101  2023-01-02 09:19:59     32.71     -92.53  10.35
#
# ...

# %%
df.isna().sum()
# Out:
# trip_id                         0
# driver_id                       0
# timestamp                       0
# latitude                        0
# longitude                       0
# speed                           0
# acceleration                    0
# steering_angle                  0
# trip_duration                   0
# trip_distance                   0
# fuel_consumption                0
# brake_usage                     0
# weather_conditions              0
# road_type                       0
# traffic_condition               0
# stop_events                     0
# geofencing_violation            0
# anomalous_event                 0
# route_anomaly                   0
# route_deviation_score           0
# acceleration_variation          0
# behavioral_consistency_index    0
# dtype: int64

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [trip_id, driver_id, timestamp, latitude, longitude, speed, acceleration, steering_angle, trip_duration, trip_distance, fuel_consumption, brake_usage, weather_conditions, road_type, traffic_condition, stop_events, geofencing_violation, anomalous_event, route_anomaly, route_deviation_score, acceleration_variation, behavioral_consistency_index]
# Index: []

# %%
print(df['stop_events'].value_counts())
# Out:
# stop_events
# 0    44419
# 1    44077
# 2    21764
# 3     7472
# 4     1837
# 5      352
# 6       67
# 7       11
# 8        1
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (120000, 22)

# %%
print(df['driver_id'].value_counts())
# Out:
# driver_id
# 101    59888
# 102    24163
# 104    12204
# 103    11945
# 105    11800
# Name: count, dtype: int64

# %%
df.to_csv("../Driver Behavior and Route Anomaly Dataset/driver_behavior_cleaned.csv", index=False)
print("Saved successfully!")
# Out:
# Saved successfully!

# %%
import os
os.listdir("..")
# Out:
# ['.ipynb_checkpoints',
#  'Delivery truck trips data',
#  'DeliveryTruckTripsData_cleaned.ipynb',
#  'Driver Behavior and Route Anomaly Dataset',
#  'Driving Behavior',
#  'Highway Traffic Videos',
#  'notebooks',
#  'Traffic_Violations.csv',
#  'Transportation ang Logistics Tracking Datasets',
#  'Untitled.ipynb',
#  'Yolo Truck Datasets']
