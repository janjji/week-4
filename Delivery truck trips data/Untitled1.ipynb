# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
pd.set_option('display.max_columns', None)

# %%
os.listdir("week 4-5/Driver Behavior and Route Anomaly Dataset")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 os.listdir("week 4-5/Driver Behavior and Route Anomaly Dataset")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'week 4-5/Driver Behavior and Route Anomaly Dataset'

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\yjany\week 4-5\Delivery truck trips data
